# %% [markdown]
# Mathmatics

# %%
import numpy as np

# %%
a=np.array([1,2,3,4])
print(a)
# Out:
# [1 2 3 4]

# %%
a+2
# Out:
# array([3, 4, 5, 6])

# %%
a-2
# Out:
# array([-1,  0,  1,  2])

# %%
a*2
# Out:
# array([2, 4, 6, 8])

# %%
a/2
# Out:
# array([0.5, 1. , 1.5, 2. ])

# %%
b=np.array([5,6,7,8])
a+b
# Out:
# array([ 6,  8, 10, 12])

# %%
a**2
# Out:
# array([ 1,  4,  9, 16])

# %%
np.sin(a)
# Out:
# array([ 0.84147098,  0.90929743,  0.14112001, -0.7568025 ])
