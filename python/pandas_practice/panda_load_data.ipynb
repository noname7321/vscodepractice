# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('C:\\Users\\abc\\Documents\\GitHub\\vscodepractice\\python\\pandas_practice\\panda_data\\survey_results_public.csv')
# Out:
# C:\Users\abc\AppData\Local\Temp\ipykernel_60532\465996379.py:1: DtypeWarning: Columns (0: JobSatPoints_15_TEXT, 1: DatabaseHaveEntry, 2: DevEnvHaveEntry, 3: SOTagsHaveEntry, 4: SOTagsWant Entry, 5: OfficeStackWantEntry, 6: CommPlatformHaveEntr, 7: CommPlatformWantEntr, 8: SO_Actions_15_TEXT, 9: AIAgentOrchestration, 10: AIAgentObsWrite) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('C:\\Users\\abc\\Documents\\GitHub\\vscodepractice\\python\\pandas_practice\\panda_data\\survey_results_public.csv')

# %%
df.head(10)
# Out:
#    ResponseId                      MainBranch              Age  \
# 0           1  I am a developer by profession  25-34 years old
# 1           2  I am a developer by profession  25-34 years old
# 2           3  I am a developer by profession  35-44 years old
# 3           4  I am a developer by profession  35-44 years old
# 4           5  I am a developer by profession  35-44 years old
# 5           6  I am a developer by profession  45-54 years old
# 6           7  I am a developer by profession  25-34 years old
# 7           8  I am a developer by profession  35-44 years old
# 8           9  I am a developer by profession  25-34 years old
# 9          10  I am a developer by profession  25-34 years old
#
#                                              EdLevel  \
# 0    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1                Associate degree (A.A., A.S., etc.)
# 2       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...

# %%
df.shape #(rows,columns)
# df.shape 是一个属性（attribute），而不是方法（method）。
# 属性是对象直接存储的数据，访问时不需要加括号；而方法是需要执行的动作，调用时必须加括号 ()。
# 用属性表示对象“是什么”或“有什么”
# 用方法表示对象“能做什么”
# Out:
# (49191, 172)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 49191 entries, 0 to 49190
# Columns: 172 entries, ResponseId to JobSat
# dtypes: float64(52), int64(1), str(119)
# memory usage: 64.6 MB

# %%
pd.set_option('display.max_columns', 172)  # 显示所有列
pd.set_option('display.max_rows', 200)     # 显示所有行

# %%
schema_df = pd.read_csv('C:\\Users\\abc\\Documents\\GitHub\\vscodepractice\\python\\pandas_practice\\panda_data\\survey_results_schema.csv')
schema_df.head(10)
# Out:
#      qid           qname                                           question  \
# 0  QID18   TechEndorse_1  What attracts you to a technology or causes yo...
# 1  QID18   TechEndorse_2  What attracts you to a technology or causes yo...
# 2  QID18   TechEndorse_3  What attracts you to a technology or causes yo...
# 3  QID18   TechEndorse_4  What attracts you to a technology or causes yo...
# 4  QID18   TechEndorse_5  What attracts you to a technology or causes yo...
# 5  QID18   TechEndorse_6  What attracts you to a technology or causes yo...
# 6  QID18   TechEndorse_7  What attracts you to a technology or causes yo...
# 7  QID18   TechEndorse_8  What attracts you to a technology or causes yo...
# 8  QID18   TechEndorse_9  What attracts you to a technology or causes yo...
# 9  QID18  TechEndorse_13  What attracts you to a technology or causes yo...
#
#   type                                      sub  sq_id
# 0   RO  AI integration or AI Agent capabilities    1.0
# ...

# %%
schema_df.tail(10)
# Out:
#         qid                 qname  \
# 129   QID89      AIAgentKnowledge
# 130  QID107      AIAgentKnowWrite
# 131   QID90  AIAgentOrchestration
# 132  QID102      AIAgentOrchWrite
# 133   QID91  AIAgentObserveSecure
# 134  QID103       AIAgentObsWrite
# 135   QID92       AIAgentExternal
# 136  QID104       AIAgentExtWrite
# 137  QID100               AIHuman
# 138   QID93                AIOpen
#
#                                               question type  sub  sq_id
# 129  You indicated you use or develop AI agents as ...   MC  NaN    NaN
# 130  Was the tool or tools for AI agent orchestrati...   TE  NaN    NaN
# 131  You indicated you use or develop AI agents as ...   MC  NaN    NaN
# 132  Was the tool or tools for AI agent orchestrati...   TE  NaN    NaN
# 133  You indicated you use or develop AI agents as ...   MC  NaN    NaN
# 134  Was the tool or tools for AI agent observabili...   TE  NaN    NaN
# 135  You indicated you use or develop AI agents as ...   MC  NaN    NaN
# ...

# %%
pd.set_option('display.max_seq_items', None)
pd.set_option('display.max_columns', None)
print(list(df.columns))
# Out:
# ['ResponseId', 'MainBranch', 'Age', 'EdLevel', 'Employment', 'EmploymentAddl', 'WorkExp', 'LearnCodeChoose', 'LearnCode', 'LearnCodeAI', 'AILearnHow', 'YearsCode', 'DevType', 'OrgSize', 'ICorPM', 'RemoteWork', 'PurchaseInfluence', 'TechEndorseIntro', 'TechEndorse_1', 'TechEndorse_2', 'TechEndorse_3', 'TechEndorse_4', 'TechEndorse_5', 'TechEndorse_6', 'TechEndorse_7', 'TechEndorse_8', 'TechEndorse_9', 'TechEndorse_13', 'TechEndorse_13_TEXT', 'TechOppose_1', 'TechOppose_2', 'TechOppose_3', 'TechOppose_5', 'TechOppose_7', 'TechOppose_9', 'TechOppose_11', 'TechOppose_13', 'TechOppose_16', 'TechOppose_15', 'TechOppose_15_TEXT', 'Industry', 'JobSatPoints_1', 'JobSatPoints_2', 'JobSatPoints_3', 'JobSatPoints_4', 'JobSatPoints_5', 'JobSatPoints_6', 'JobSatPoints_7', 'JobSatPoints_8', 'JobSatPoints_9', 'JobSatPoints_10', 'JobSatPoints_11', 'JobSatPoints_13', 'JobSatPoints_14', 'JobSatPoints_15', 'JobSatPoints_16', 'JobSatPoints_15_TEXT', 'AIThreat', 'NewRole', 'ToolCountWork', 'ToolCountPerso
# ...

# %%
df['Employment'] # accessing a single column, returns a Series
# Out:
# 0                                                 Employed
# 1                                                 Employed
# 2        Independent contractor, freelancer, or self-em...
# 3                                                 Employed
# 4        Independent contractor, freelancer, or self-em...
#                                ...
# 49186                                             Employed
# 49187                                             Employed
# 49188                                             Employed
# 49189    Independent contractor, freelancer, or self-em...
# 49190                                              Student
# Name: Employment, Length: 49191, dtype: str

# %%
df['PurchaseInfluence'] # accessing a single column, returns a Series
# Out:
# 0        Yes, I influenced the purchase of a substantia...
# 1                                                       No
# 2                                                       No
# 3                                                       No
# 4        Yes, I endorsed a tool that was open-source an...
#                                ...
# 49186                                                  NaN
# 49187                                                  NaN
# 49188    Yes, I endorsed a tool that was open-source an...
# 49189                                                  NaN
# 49190                                                  NaN
# Name: PurchaseInfluence, Length: 49191, dtype: str

# %%
df['PurchaseInfluence'].value_counts()
# Out:
# PurchaseInfluence
# No                                                                                                                                    19697
# Yes, I influenced the purchase of a substantial addition to the tech stack                                                             7430
# Yes, I endorsed a tool that was open-source and is currently used by more than just myself but no purchase was made                    5794
# Yes, I influenced the purchase of a tool that more than five colleagues use but it is not a substantial addition to the tech stack     3113
# Yes, I endorsed a tool that was ultimately not purchased or used at my organization                                                    1403
# Name: count, dtype: int64

# %%
with pd.option_context('display.max_seq_items', 200, 'display.max_columns', 200):
    print(df.loc[0])  # access first row by label, returns a Series
# Out:
# ResponseId                                                                                  1
# MainBranch                                                     I am a developer by profession
# Age                                                                           25-34 years old
# EdLevel                                       Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# Employment                                                                           Employed
# EmploymentAddl                                Caring for dependents (children, elderly, etc.)
# WorkExp                                                                                   8.0
# LearnCodeChoose                             Yes, I am not new to coding but am learning ne...
# LearnCode                                   Online Courses or Certification (includes all ...
# LearnCodeAI                                 Yes, I learned how to use AI-enabled tools for...
# ...

# %%
df.loc[[0,1,2],'Age']  # access first row, Age column
# Out:
# 0    25-34 years old
# 1    25-34 years old
# 2    35-44 years old
# Name: Age, dtype: str

# %%
df.loc[0:20,'Age':'Country']  # access first three rows, Age to Country columns (inclusive)
# Out:
#                   Age                                            EdLevel  \
# 0     25-34 years old    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1     25-34 years old                Associate degree (A.A., A.S., etc.)
# 2     35-44 years old       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3     35-44 years old       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4     35-44 years old    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 5     45-54 years old    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 6     25-34 years old  Some college/university study without earning ...
# 7     35-44 years old     Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 8     25-34 years old       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 9     25-34 years old    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 10    25-34 years old    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 11    18-24 years old       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...

# %% [markdown]
# Index changing

# %%
df.set_index('ResponseId', inplace=True)  # sets Respondent as index, modifies original DataFrame
df.head(10)
# Out:
#                                 MainBranch              Age  \
# ResponseId
# 1           I am a developer by profession  25-34 years old
# 2           I am a developer by profession  25-34 years old
# 3           I am a developer by profession  35-44 years old
# 4           I am a developer by profession  35-44 years old
# 5           I am a developer by profession  35-44 years old
# 6           I am a developer by profession  45-54 years old
# 7           I am a developer by profession  25-34 years old
# 8           I am a developer by profession  35-44 years old
# 9           I am a developer by profession  25-34 years old
# 10          I am a developer by profession  25-34 years old
#
#                                                       EdLevel  \
# ResponseId
# 1             Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2                         Associate degree (A.A., A.S., etc.)
# 3                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...

# %%
schema_df.set_index('qname', inplace=True)  # sets Column as index, modifies original DataFrame
schema_df.head(10)
# Out:
#                   qid                                           question type  \
# qname
# TechEndorse_1   QID18  What attracts you to a technology or causes yo...   RO
# TechEndorse_2   QID18  What attracts you to a technology or causes yo...   RO
# TechEndorse_3   QID18  What attracts you to a technology or causes yo...   RO
# TechEndorse_4   QID18  What attracts you to a technology or causes yo...   RO
# TechEndorse_5   QID18  What attracts you to a technology or causes yo...   RO
# TechEndorse_6   QID18  What attracts you to a technology or causes yo...   RO
# TechEndorse_7   QID18  What attracts you to a technology or causes yo...   RO
# TechEndorse_8   QID18  What attracts you to a technology or causes yo...   RO
# TechEndorse_9   QID18  What attracts you to a technology or causes yo...   RO
# TechEndorse_13  QID18  What attracts you to a technology or causes yo...   RO
#
#                                                     sub  sq_id
# qname
# ...

# %%
schema_df.loc['Industry','question']
# Out:
# 'What industry do you work for in?'

# %%
schema_df.sort_index(inplace=True,ascending=True)  # sorts schema_df by index (qname)
schema_df.head(10)
# Out:
#                          qid  \
# qname
# AIAcc                  QID80
# AIAgentChallenges      QID88
# AIAgentChange          QID83
# AIAgentExtWrite       QID104
# AIAgentExternal        QID92
# AIAgentImpact          QID87
# AIAgentKnowWrite      QID107
# AIAgentKnowledge       QID89
# AIAgentObsWrite       QID103
# AIAgentObserveSecure   QID91
#
#                                                                question  \
# qname
# AIAcc                 How much do you trust the accuracy of the outp...
# AIAgentChallenges     To what extent do you agree with the following...
# AIAgentChange         Have AI tools or AI agents changed how you com...
# AIAgentExtWrite       Was the out-of-the-box agents, copilots or ass...
# AIAgentExternal       You indicated you use or develop AI agents as ...
# AIAgentImpact         To what extent do you agree with the following...
# AIAgentKnowWrite      Was the tool or tools for AI agent orchestrati...
# ...

# %%
df['CompTotal'].nlargest(10)  # top 10 largest values in 'CompTotal' column
# Out:
# ResponseId
# 4934     5.555556e+74
# 44527    8.000000e+23
# 35765    1.000000e+23
# 28546    9.223372e+18
# 22733    1.000000e+17
# 484      1.000000e+16
# 18755    1.000000e+15
# 39338    9.596957e+11
# 35354    6.500000e+11
# 39350    1.000000e+11
# Name: CompTotal, dtype: float64

# %%
df.nsmallest(10, 'CompTotal')  # bottom 10 smallest values in 'CompTotal' column
# Out:
#                                                    MainBranch  \
# ResponseId
# 99          I am not primarily a developer, but I write co...
# 182         I am not primarily a developer, but I write co...
# 216         I am not primarily a developer, but I write co...
# 236                            I am a developer by profession
# 263                            I am a developer by profession
# 319                            I am a developer by profession
# 384         I work with developers or my work supports dev...
# 393         I used to be a developer by profession, but no...
# 418         I used to be a developer by profession, but no...
# 429         I am not primarily a developer, but I write co...
#
#                           Age  \
# ResponseId
# 99            18-24 years old
# 182           18-24 years old
# 216           18-24 years old
# 236           25-34 years old
# 263         65 years or older
# 319           35-44 years old
# 384           18-24 years old
# ...
