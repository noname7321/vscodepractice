# %%
import pandas as pd
import numpy as np
df = pd.read_csv('C:\\Users\\abc\\Documents\\GitHub\\vscodepractice\\python\\pandas_practice\\panda_data\\survey_results_public.csv')
schema_df = pd.read_csv('C:\\Users\\abc\\Documents\\GitHub\\vscodepractice\\python\\pandas_practice\\panda_data\\survey_results_schema.csv')
# Out:
# C:\Users\abc\AppData\Local\Temp\ipykernel_41716\2121301145.py:3: DtypeWarning: Columns (0: JobSatPoints_15_TEXT, 1: DatabaseHaveEntry, 2: DevEnvHaveEntry, 3: SOTagsHaveEntry, 4: SOTagsWant Entry, 5: OfficeStackWantEntry, 6: CommPlatformHaveEntr, 7: CommPlatformWantEntr, 8: SO_Actions_15_TEXT, 9: AIAgentOrchestration, 10: AIAgentObsWrite) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('C:\\Users\\abc\\Documents\\GitHub\\vscodepractice\\python\\pandas_practice\\panda_data\\survey_results_public.csv')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head()
# Out:
#    ResponseId                      MainBranch              Age  \
# 0           1  I am a developer by profession  25-34 years old
# 1           2  I am a developer by profession  25-34 years old
# 2           3  I am a developer by profession  35-44 years old
# 3           4  I am a developer by profession  35-44 years old
# 4           5  I am a developer by profession  35-44 years old
#
#                                            EdLevel  \
# 0  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1              Associate degree (A.A., A.S., etc.)
# 2     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                           Employment  \
# 0                                           Employed
# 1                                           Employed
# 2  Independent contractor, freelancer, or self-em...
# 3                                           Employed
# ...

# %%
df['YearsCode']
# Out:
# 0        14.0
# 1        10.0
# 2        12.0
# 3         5.0
# 4        22.0
#          ...
# 49186     NaN
# 49187     NaN
# 49188    31.0
# 49189     NaN
# 49190     6.0
# Name: YearsCode, Length: 49191, dtype: float64

# %%
longtimecoders = df['YearsCode'] >= 25
longtimecoders.value_counts()
# Out:
# YearsCode
# False    38749
# True     10442
# Name: count, dtype: int64

# %%
df[longtimecoders]
# Out:
#        ResponseId                                         MainBranch  \
# 7               8                     I am a developer by profession
# 16             17  I am not primarily a developer, but I write co...
# 20             21  I am not primarily a developer, but I write co...
# 21             22  I am not primarily a developer, but I write co...
# 24             25                     I am a developer by profession
# ...           ...                                                ...
# 49130       49131                     I am a developer by profession
# 49145       49146                     I am a developer by profession
# 49161       49162  I used to be a developer by profession, but no...
# 49178       49179                     I am a developer by profession
# 49188       49189                     I am a developer by profession
#
#                      Age                                            EdLevel  \
# ...

# %%
df.loc[longtimecoders, ['Country', 'YearsCode','Employment','AISelect'] ]
# Out:
#                         Country  YearsCode  \
# 7                       Ukraine       30.0
# 16                    Australia       40.0
# 20                       Brazil       45.0
# 21     United States of America       35.0
# 24                    Lithuania       47.0
# ...                         ...        ...
# 49130                   Germany       40.0
# 49145  United States of America       30.0
# 49161                Costa Rica       27.0
# 49178                   Germany       25.0
# 49188                     Italy       31.0
#
#                                               Employment  \
# 7                                               Employed
# 16                                               Retired
# 20                                              Employed
# 21                                              Employed
# 24     Independent contractor, freelancer, or self-em...
# ...                                                  ...
# ...

# %%
countries = ['India', 'United States of America', 'Germany', 'Canada', 'Italy']
filt = df['Country'].isin(countries) & longtimecoders
df.loc[filt, ['Country', 'YearsCode','Employment','AISelect'] ]
# Out:
#                         Country  YearsCode  \
# 21     United States of America       35.0
# 33     United States of America       26.0
# 37     United States of America       25.0
# 40     United States of America       38.0
# 41     United States of America       25.0
# ...                         ...        ...
# 49123  United States of America       25.0
# 49130                   Germany       40.0
# 49145  United States of America       30.0
# 49178                   Germany       25.0
# 49188                     Italy       31.0
#
#                                               Employment  \
# 21                                              Employed
# 33                                              Employed
# 37                                              Employed
# 40                                              Employed
# 41                                              Employed
# ...                                                  ...
# ...

# %%
shorttimecoders = df['YearsCode'] >= 5
df.loc[shorttimecoders, 'LanguageHaveWorkedWith']
# Out:
# 0                         Bash/Shell (all shells);Dart;SQL
# 1                                                     Java
# 2                      Dart;HTML/CSS;JavaScript;TypeScript
# 3                                          Java;Kotlin;SQL
# 4        C;C#;C++;Delphi;HTML/CSS;Java;JavaScript;Lua;P...
#                                ...
# 49178                   Bash/Shell (all shells);C;C++;Rust
# 49179                        Bash/Shell (all shells);Swift
# 49180                  Assembly;C#;Go;Java;JavaScript;Rust
# 49188                                                  NaN
# 49190                                                  NaN
# Name: LanguageHaveWorkedWith, Length: 38449, dtype: str

# %%
filt1 = df['LanguageHaveWorkedWith'].str.contains('Python', na=False) & shorttimecoders
df[filt1]
# Out:
#        ResponseId                                         MainBranch  \
# 4               5                     I am a developer by profession
# 7               8                     I am a developer by profession
# 8               9                     I am a developer by profession
# 17             18                     I am a developer by profession
# 19             20  I am not primarily a developer, but I write co...
# ...           ...                                                ...
# 49142       49143                        I code primarily as a hobby
# 49143       49144                     I am a developer by profession
# 49145       49146                     I am a developer by profession
# 49175       49176                     I am a developer by profession
# 49176       49177                     I am a developer by profession
#
#                    Age                                            EdLevel  \
# ...

# %%
# Out:
#        ResponseId                                         MainBranch  \
# 4               5                     I am a developer by profession
# 7               8                     I am a developer by profession
# 8               9                     I am a developer by profession
# 17             18                     I am a developer by profession
# 19             20  I am not primarily a developer, but I write co...
# ...           ...                                                ...
# 49142       49143                        I code primarily as a hobby
# 49143       49144                     I am a developer by profession
# 49145       49146                     I am a developer by profession
# 49175       49176                     I am a developer by profession
# 49176       49177                     I am a developer by profession
#
#                    Age                                            EdLevel  \
# ...
