# %%
import pandas as pd
import numpy as np

df = pd.read_csv('panda_data/survey_results_public.csv', index_col='ResponseId')
schema_df = pd.read_csv('panda_data/survey_results_schema.csv')#, index_col='Column')
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)
df.head()
# Out:
# C:\Users\abc\AppData\Local\Temp\ipykernel_27916\1602831184.py:4: DtypeWarning: Columns (0: AIThreat, 1: DatabaseWantEntry, 2: DevEnvWantEntry, 3: SOTagsWant Entry, 4: OpSysPersonal use, 5: CommPlatformHaveWorkedWith, 6: CommPlatformWantEntr, 7: AIModelsChoice, 8: SOComm, 9: AIAgentOrchWrite, 10: AIAgentExternal) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('panda_data/survey_results_public.csv', index_col='ResponseId')
#                                 MainBranch              Age  \
# ResponseId
# 1           I am a developer by profession  25-34 years old
# 2           I am a developer by profession  25-34 years old
# 3           I am a developer by profession  35-44 years old
# 4           I am a developer by profession  35-44 years old
# 5           I am a developer by profession  35-44 years old
#
#                                                     EdLevel  \
# ResponseId
# ...

# %%
filt= (df['Country'] == 'India') 
india_df= df.loc[filt]
india_df.head()
# Out:
#                                 MainBranch              Age  \
# ResponseId
# 14          I am a developer by profession  25-34 years old
# 16          I am a developer by profession  18-24 years old
# 47          I am a developer by profession  35-44 years old
# 91          I am a developer by profession  25-34 years old
# 134         I am a developer by profession  25-34 years old
#
#                                                  EdLevel Employment  \
# ResponseId
# 14          Bachelor’s degree (B.A., B.S., B.Eng., etc.)   Employed
# 16          Bachelor’s degree (B.A., B.S., B.Eng., etc.)    Student
# 47          Bachelor’s degree (B.A., B.S., B.Eng., etc.)   Employed
# 91          Bachelor’s degree (B.A., B.S., B.Eng., etc.)   Employed
# 134         Bachelor’s degree (B.A., B.S., B.Eng., etc.)   Employed
#
#                                                EmploymentAddl  WorkExp  \
# ResponseId
# 14            Caring for dependents (children, elderly, etc.)      6.0
# ...

# %%
india_df.to_csv('C:\\Users\\abc\\Documents\\GitHub\\vscodepractice\\python\\pandas_practice\\panda_data\\india_survey_results.csv')

# %%
india_df.to_csv('C:\\Users\\abc\\Documents\\GitHub\\vscodepractice\\python\\pandas_practice\\panda_data\\india_survey_results.psv', sep='\t')

# %%
india_df.to_excel('panda_data/india_survey_results.xlsx', sheet_name='India Survey Results')

# %%
test=pd.read_excel('panda_data/india_survey_results.xlsx', sheet_name='India Survey Results',index_col='ResponseId')
test.head()
# Out:
#                                 MainBranch              Age  \
# ResponseId
# 14          I am a developer by profession  25-34 years old
# 16          I am a developer by profession  18-24 years old
# 47          I am a developer by profession  35-44 years old
# 91          I am a developer by profession  25-34 years old
# 134         I am a developer by profession  25-34 years old
#
#                                                  EdLevel Employment  \
# ResponseId
# 14          Bachelor’s degree (B.A., B.S., B.Eng., etc.)   Employed
# 16          Bachelor’s degree (B.A., B.S., B.Eng., etc.)    Student
# 47          Bachelor’s degree (B.A., B.S., B.Eng., etc.)   Employed
# 91          Bachelor’s degree (B.A., B.S., B.Eng., etc.)   Employed
# 134         Bachelor’s degree (B.A., B.S., B.Eng., etc.)   Employed
#
#                                                EmploymentAddl  WorkExp  \
# ResponseId
# 14            Caring for dependents (children, elderly, etc.)      6.0
# ...

# %%
india_df.to_json('panda_data/india_survey_results.json', orient='records', lines=True)
# orient='records' creates a list of dictionaries, where each dictionary represents a row in the DataFrame.
# lines=True writes each dictionary on a separate line in the JSON file, making it easier to read and process large JSON files.

# %%
test_json = pd.read_json('panda_data/india_survey_results.json', orient='records', lines=True)
test_json.head()
# Out:
#                        MainBranch              Age  \
# 0  I am a developer by profession  25-34 years old
# 1  I am a developer by profession  18-24 years old
# 2  I am a developer by profession  35-44 years old
# 3  I am a developer by profession  25-34 years old
# 4  I am a developer by profession  25-34 years old
#
#                                         EdLevel Employment  \
# 0  Bachelor’s degree (B.A., B.S., B.Eng., etc.)   Employed
# 1  Bachelor’s degree (B.A., B.S., B.Eng., etc.)    Student
# 2  Bachelor’s degree (B.A., B.S., B.Eng., etc.)   Employed
# 3  Bachelor’s degree (B.A., B.S., B.Eng., etc.)   Employed
# 4  Bachelor’s degree (B.A., B.S., B.Eng., etc.)   Employed
#
#                                       EmploymentAddl  WorkExp  \
# 0    Caring for dependents (children, elderly, etc.)      6.0
# 1  Engaged in paid work (20-29 hours per week);En...      5.0
# 2                           Volunteering (regularly)      NaN
# ...

# %%
from sqlalchemy import create_engine
import psycopg2

# %%
engine= create_engine('postgresql://username:password@localhost:5432/mydatabase')

# %%
india_df.to_sql('sample_table',engine, if_exists='replace', index=False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sqlalchemy\engine\base.py:143, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     142 try:
# --> 143     self._dbapi_connection = engine.raw_connection()
#     144 except dialect.loaded_dbapi.Error as err:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sqlalchemy\engine\base.py:3309, in Engine.raw_connection(self)
#    3288 """Return a "raw" DBAPI connection from the connection pool.
#    3289
#    3290 The returned object is a proxied version of the DBAPI
#    (...)   3307
#    3308 """
# -> 3309 return self.pool.connect()
#
# ...

# %%
sql_df = pd.read_sql('sample_table', engine,index_col='ResponseId' )
# The read_sql() function allows you to read a SQL query or database table into a DataFrame. 
# In this example, we are reading the entire 'sample_table' from the database and setting 'ResponseId' as the index column.

# %%
sql_df = pd.read_sql_query('SELECT * FROM sample_table WHERE Age > 25', engine, index_col='ResponseId')
# The read_sql_query() function allows you to execute a SQL query directly and return the result as a DataFrame.
#  In this example, we are selecting all records from the 'sample_table' where the 'Age' column is greater than 25.
